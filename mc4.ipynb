# %%
from tcplFit2 import tcplFit2
from load_mc3_data import load_mc3_data
from tcplMthdLoad import tcplMthdLoad
from mc4_mthds import mc4_mthds

id = 5
# fitmodels = ["cnst", "hill", "gnls", "poly1", "poly2", "pow", "exp2", "exp3", "exp4", "exp5"]
fitmodels = ["cnst"]

df = load_mc3_data(id) #.head(100)
ms = tcplMthdLoad(lvl = 4, id = id, type = "mc")

if (ms.shape[0] == 0):
    print(f"No level 4 methods for AEID {id} Level 4 processing incomplete; no updates made to the mc4.")

mthd_funcs = mc4_mthds()

for method_key in ms['mthd'].tolist():
    df = mthd_funcs.get(method_key)(df)

# fit
bidirectional = True
df = tcplFit2(df, fitmodels=fitmodels, bidirectional=bidirectional)
print(df.head(1))
# Out:
# c:\Users\bossh\Documents\GitHub\tox\tcplQuery.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, db)
# [{'cnst': {'success': 1, 'aic': 46.89757679243235, 'rme': 0.07900264583170341, 'er': -2.7775606126965853, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': -6.638059092688264, 'rme': 0.48905790586514114, 'er': -2.2409880387586645, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 38.992209006999865, 'rme': 0.08851823576414916, 'er': -2.5045356560901335, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 58.520521170836545, 'rme': 0.05653582361721731, 'er': -3.033474638539169, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 44.02534706237384, 'rme': 0.07988197921416516, 'er': -2.6588140023273525, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 54.90845258779369, 'rme': 0.060874321096851494, 'er': -2.9264217443761686, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 47.56000187243637, 'rme': 0.07272015965293609, 'er': -2.7375565216434965, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 70.01572416815054, 'rme': 0.04315975173632474, 'er': -3.3403636366581377, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 49.94413368267921, 'rme': 0.07119092940096113, 'er': -2.837252802170555, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 21.876178173167126, 'rme': 0.14127806378302946, 'er': -2.119082583923839, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 48.15904812743657, 'rme': 0.07052850722177004, 'er': -2.7324453886404134, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 71.90047013691152, 'rme': 0.038876969025980194, 'er': -3.3280003638973588, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 92.47681864170234, 'rme': 0.02570609063480761, 'er': -3.9114595483312304, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 83.87798024083318, 'rme': 0.02960525969773456, 'er': -3.6573908641711195, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 94.63667323967674, 'rme': 0.02309145162581316, 'er': -3.9453917921472708, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 68.6301696786945, 'rme': 0.04450568586771057, 'er': -3.277752465651185, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': -29.50058386407348, 'rme': 0.7879136466613837, 'er': -1.510007449833816, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 24.52981430491522, 'rme': 0.16549255171550242, 'er': -2.373974194710455, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 65.97971918252263, 'rme': 0.04508767832285729, 'er': -3.179122927202379, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 53.11919154669698, 'rme': 0.0632869809677807, 'er': -2.8747703841615415, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 67.56125850406144, 'rme': 0.047075196313108275, 'er': -3.2954375506606506, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 29.332289463838144, 'rme': 0.1161378515681582, 'er': -2.300721619225535, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 47.78417426292588, 'rme': 0.07857520362667991, 'er': -2.832645158207772, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 59.69647802611646, 'rme': 0.05376265055596057, 'er': -3.0416151067292185, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 72.1732133178949, 'rme': 0.04007893256143972, 'er': -3.369881170027004, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 77.23484212438191, 'rme': 0.03640266813295006, 'er': -3.530395878995202, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 72.8398679562125, 'rme': 0.039734567327597024, 'er': -3.402029160256058, 'pars': 'er'}, 'modelnames': ['cnst']}, {'cnst': {'success': 1, 'aic': 80.43516781465667, 'rme': 0.03227639677473072, 'er': -3.57319 ...
#    aeid          spid      bmad  resp_max  osd  bmed  resp_min  max_mean
# 0     5  TP0000073A01  0.055697  0.187195  NaN     0  -0.09775  0.090562  \
#
#    max_mean_conc   max_med  ...  logc_max  logc_min  nconc  npts  nrep
# 0        1.30103  0.090562  ...   2.30103  -0.39794     10    20   2.0  \
#
#    nmed_gtbl                             concentration_unlogged
# 0        0.0  [0.39999999999999963, 0.8, 1.999999999999999, ...  \
#
#                                             response
# 0  [-0.0871974214694476, -0.0977499173617988, -0....  \
#
#                                                m3ids tmpi
# 0  [152106513, 152106514, 152106515, 152106516, 1...  320
#
# [1 rows x 21 columns]
